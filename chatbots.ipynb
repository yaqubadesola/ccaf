# %%
from dotenv import load_dotenv
load_dotenv()
from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5-20251001"

# %%
system_prompt = """
You are patient teacher, Explain with clean examples of how to solve mathematics probles
"""
def add_user_message(messages, text):
    user_message={"role":"user", "content":text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message={"role":"assistant", "content":text}
    messages.append(assistant_message)
    
def chat(messages,system_prompt):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
        system=system_prompt
    )

    return message.content[0].text

# %%
# Start with an empty message list
messages = []
while True:
    
    input = input("> ")
    user_text = input
    print("=========")
    print(">",user_text)
    print("=========")
    # Add the initial user question
    add_user_message(messages, user_text)

    # Get Claude's response
    answer = chat(messages,system_prompt)
    
    # Add Claude's response to the conversation history
    add_assistant_message(messages, answer)

    print("=========")
    print(answer)
    print("=========")
# Out:
# =========
# > How do I solve 2x+4 =0
# =========
# =========
# # Solving 2x + 4 = 0
#
# Great question! Let me walk you through this step-by-step.
#
# ## Step 1: Get the term with x by itself
# We need to move the **4** to the other side of the equation.
# - Subtract 4 from both sides:
#
# $$2x + 4 - 4 = 0 - 4$$
# $$2x = -4$$
#
# ## Step 2: Isolate x
# Now divide both sides by **2**:
#
# $$\frac{2x}{2} = \frac{-4}{2}$$
# $$x = -2$$
#
# ## ✓ Check Your Answer
# Let's verify by plugging x = -2 back into the original equation:
#
# $$2(-2) + 4 = -4 + 4 = 0$$ ✓
#
# **So x = -2 is correct!**
#
# ---
#
# ## Quick Summary
# The goal is always to:
# 1. **Move numbers** away from the x (using addition/subtraction)
# 2. **Get x alone** (using multiplication/division)
#
# Does this make sense? Would you like me to explain any step in more detail?
# =========
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 # Start with an empty message list
#       2 messages = []
#       3 while True:
#       4
# ----> 5     input = input("> ")
#       6     user_text = input
#       7     print("=========")
#       8     print(">",user_text)
#
# TypeError: 'str' object is not callable
